# %%
import numpy as np
import pandas as pd
import pylab as plot

# %pylab inline
# Out:
# Populating the interactive namespace from numpy and matplotlib
# /Users/nkwjones/anaconda3/lib/python3.6/site-packages/IPython/core/magics/pylab.py:160: UserWarning: pylab import has clobbered these variables: ['plot']
# `%matplotlib` prevents importing * from pylab and numpy
#   "\n`%matplotlib` prevents importing * from pylab and numpy"

# %%
df = pd.read_csv('Municipal_income.csv')
df.Income=pd.to_numeric(df.Income, )
df.drop('State_code',axis=1,inplace=True)
df.head(2)
# Out:
#             State  Muni_code    Municipality  Income
# 0  Aguascalientes       1001  Aguascalientes    3530
# 1  Aguascalientes       1002        Asientos    1360

# %%
print("There are {} municipalities. \n".format(df.shape[0]))
      
print("Lowest income is {} with ${}/month. \n".format(
    df.Municipality.loc[df.Income.idxmin()], df.Income.min()))

print("Highest income is {} with ${}/month. \n".format(
    df.Municipality.loc[df.Income.idxmax()], df.Income.max()))

print("Mean monthly household income is ${:.2f} with standard deviation ${:.2f}. \n".format(
    df.Income.mean(),df.Income.std()))
# Out:
# There are 2456 municipalities.
#
# Lowest income is San Simón Zahuatlán with $415/month.
#
# Highest income is Benito Juárez with $8902/month.
#
# Mean monthly household income is $1575.35 with standard deviation $856.73.

# %%
plt.figure(figsize = [6,6])
plt.hist(df.Income,bins=100)
plt.xlabel()
plt.title("Histogram of income in Mexico's municipalities");

# %%
! ls
# Out:
# Mex_data.ipynb Mex_data.py    README.md      _config.yml    mex.png

# %%
from IPython.display import Image
Image(filename='mex.png')

# %% [markdown]
# ## Data source:
#
# https://www.coneval.org.mx/Medicion/MP/Paginas/Medicion-de-la-pobreza-municipal-2010-EN.aspx
